# %% [markdown]
# # Use Python to open csv files¶
# We will use the pandas library to work with our dataset. Pandas is a popular Python library for data science. It offers powerful and flexible data structures to make data manipulationa and analysis easier.
#
# Import Pandas

# %%
# use of panda lib
import pandas as pd

# %%
#data is a variable(can be any meaningful name) 
data=pd.read_csv("C:/Users/Lenovo/Desktop/class10dt.csv")

# %%
#head () id used to display the data 
data.head()
# Out:
#                  NAME  ADM NO CLASS SKILLED
# 0  Abhay Krishna .P.M    1741    XA      AI
# 1     ABHIRAM M SHAJU    2220    XA      AI
# 2    Abhishek K Gopan    1851    XA      AI
# 3           ADARSH MS    1775    XA      AI
# 4             Adith A    1800    XA      AI

# %% [markdown]
# # Task 1: Display the first 20 rows of data by modifying the function above

# %%
data.head(20)
# Out:
#                       NAME  ADM NO CLASS SKILLED
# 0       Abhay Krishna .P.M    1741    XA      AI
# 1          ABHIRAM M SHAJU    2220    XA      AI
# 2         Abhishek K Gopan    1851    XA      AI
# 3                ADARSH MS    1775    XA      AI
# 4                  Adith A    1800    XA      AI
# 5       ADITHKRISHNA. O. K    1869    XA      AI
# 6              Aditya Ajay    1746    XA      AI
# 7         ANANDHAKRISHNA V    1813    XA      AI
# 8      Ananthakrishnan.N.A    1740    XA      AI
# 9          Annmarie Vinish    3702    XA      AI
# 10               ARJUN V R    1900    XA      AI
# 11             Devika .P.R    1749    XA      AI
# 12              Dona Maria    1751    XA      AI
# 13            GAYATHRI P R    1826    XA      AI
# 14      K.S.Utham Sreedhar    1810    XA      AI
# 15             Krishna M J    1807    XA      AI
# 16  Lakshmipriya Sreekumar    1792    XA      AI
# 17  PAVITRA SUDHIR WARRIER    3708    XA      AI
# ...

# %% [markdown]
# # Task 2: What does dtypes do?

# %%
data.dtypes?

# %%
# dtypes to know the datatype
data.dtypes
# Out:
# NAME       object
# ADM NO      int64
# CLASS      object
# SKILLED    object
# dtype: object

# %% [markdown]
# # Task 3 :To drop columns

# %%
data.drop(["SKILLED"],axis=1)
# Out:
#                        NAME  ADM NO CLASS
# 0        Abhay Krishna .P.M    1741    XA
# 1           ABHIRAM M SHAJU    2220    XA
# 2          Abhishek K Gopan    1851    XA
# 3                 ADARSH MS    1775    XA
# 4                   Adith A    1800    XA
# ..                      ...     ...   ...
# 106         SIVANI P SURESH    1883    XD
# 107        SREE PARVATHY PS    3087    XD
# 108     Sreesanth S Warrier    1801    XD
# 109  Vishnu P Raghunandanan    1809    XD
# 110           Vivekanand MV    1805    XD
#
# [111 rows x 3 columns]

# %% [markdown]
# # Task 4: Drop the following columns(more than one columns)

# %%
data.drop(["NAME","CLASS"],axis=1)
# Out:
#      ADM NO SKILLED
# 0      1741      AI
# 1      2220      AI
# 2      1851      AI
# 3      1775      AI
# 4      1800      AI
# ..      ...     ...
# 106    1883      AI
# 107    3087      AI
# 108    1801      AI
# 109    1809      AI
# 110    1805      AI
#
# [111 rows x 2 columns]

# %% [markdown]
# # To drop a row

# %%
data.drop([3,4],axis=0)
# Out:
#                        NAME  ADM NO CLASS SKILLED
# 0        Abhay Krishna .P.M    1741    XA      AI
# 1           ABHIRAM M SHAJU    2220    XA      AI
# 2          Abhishek K Gopan    1851    XA      AI
# 5        ADITHKRISHNA. O. K    1869    XA      AI
# 6               Aditya Ajay    1746    XA      AI
# ..                      ...     ...   ...     ...
# 106         SIVANI P SURESH    1883    XD      AI
# 107        SREE PARVATHY PS    3087    XD      AI
# 108     Sreesanth S Warrier    1801    XD      AI
# 109  Vishnu P Raghunandanan    1809    XD      AI
# 110           Vivekanand MV    1805    XD      AI
#
# [109 rows x 4 columns]

# %% [markdown]
# # Task 5: Now check again if these collumns/rowshave been dropped

# %%
dt=data.drop([3,4],axis=0)
dt.head()
# Out:
#                  NAME  ADM NO CLASS SKILLED
# 0  Abhay Krishna .P.M    1741    XA      AI
# 1     ABHIRAM M SHAJU    2220    XA      AI
# 2    Abhishek K Gopan    1851    XA      AI
# 5  ADITHKRISHNA. O. K    1869    XA      AI
# 6         Aditya Ajay    1746    XA      AI

# %% [markdown]
# # Sorting values using pandas

# %%
#import the jaipurcleandata csv file

# %%
dt=pd.read_csv("C:/Users/Lenovo/Desktop/JaipurFinalCleanData.csv")

# %%
dt.head()
# Out:
#          date  mean_temperature  max_temperature  min_temperature  \
# 0  2016-05-04                34               41               27
# 1  2016-05-05                31               38               24
# 2  2016-05-06                28               34               21
# 3  2016-05-07                30               38               23
# 4  2016-05-08                34               41               26
#
#    Mean_dew_pt  mean_pressure  max_humidity  min_humidity  max_dew_pt_1  \
# 0            6        1006.00            27             5            12
# 1            7        1005.65            29             6            13
# 2           11        1007.94            61            13            16
# 3           13        1008.39            69            18            17
# 4           10        1007.62            50             8            14
#
#    max_dew_pt_2  min_dew_pt_1  min_dew_pt_2  max_pressure_1  max_pressure_2  \
# ...

# %%
dt.sort_values(by="max_temperature",ascending=False)
# Out:
#            date  mean_temperature  max_temperature  min_temperature  \
# 16   2016-05-20                38               46               30
# 15   2016-05-19                38               46               29
# 388  2017-05-27                38               45               32
# 17   2016-05-21                38               45               32
# 34   2016-06-07                38               45               30
# ..          ...               ...              ...              ...
# 268  2017-01-27                14               19               10
# 253  2017-01-12                12               19                4
# 251  2017-01-10                13               19                7
# 267  2017-01-26                16               18               14
# 252  2017-01-11                10               18                3
#
#      Mean_dew_pt  mean_pressure  max_humidity  min_humidity  max_dew_pt_1  \
# 16             6         998.96            33             4            13
# ...

# %% [markdown]
# # Task 6: Sort the values in ascending order of mean temperature and print the first 5 rows

# %%
jp=dt.sort_values(by="mean_temperature",ascending=True)

# %%
jp.head(5)
# Out:
#            date  mean_temperature  max_temperature  min_temperature  \
# 252  2017-01-11                10               18                3
# 253  2017-01-12                12               19                4
# 254  2017-01-13                12               20                4
# 255  2017-01-14                12               20                5
# 258  2017-01-17                12               20                5
#
#      Mean_dew_pt  mean_pressure  max_humidity  min_humidity  max_dew_pt_1  \
# 252            3        1017.00            94            17             9
# 253           -3        1017.54            70            13             2
# 254           -5        1017.24            75             4             2
# 255           -1        1017.75            70            10             1
# 258            3        1017.35            74            15             7
#
#      max_dew_pt_2  min_dew_pt_1  min_dew_pt_2  max_pressure_1  max_pressure_2  \
# ...

# %% [markdown]
# # Task 7: Sort the values in descending order of mean temperature and print the first 5 rows

# %%
jp=dt.sort_values(by="mean_temperature",ascending=False)

# %%
jp.head(5)
# Out:
#           date  mean_temperature  max_temperature  min_temperature  \
# 32  2016-06-05                38               45               31
# 15  2016-05-19                38               46               29
# 31  2016-06-04                38               44               31
# 34  2016-06-07                38               45               30
# 35  2016-06-08                38               44               31
#
#     Mean_dew_pt  mean_pressure  max_humidity  min_humidity  max_dew_pt_1  \
# 32            5        1004.67            27             4            18
# 15           11         999.88            45             5            17
# 31           13        1004.93            34            10            18
# 34           13        1003.29            51             5            21
# 35           12        1002.83            47             4            22
#
#     max_dew_pt_2  min_dew_pt_1  min_dew_pt_2  max_pressure_1  max_pressure_2  \
# ...

# %% [markdown]
# # # Learn how to explore these data visually.

# %% [markdown]
# Matplotlib is a Python 2D plotting library that we can use to produce high quality data visualization. It is highly usable (as you will soon find out), you can create simple and complex graphs with just a few lines of codes!
#
# Now let's load matplotlib to start plotting some graphs

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([0,1,2,3])
plt.show()

# %% [markdown]
# You may be wondering why the x-axis ranges from 0-3 and the y-axis from 1-4. If you provide a single list or array to the plot() command, matplotlib assumes it is a sequence of y values, and automatically generates the x values for you. Since python ranges start with 0, the default x vector has the same length as y but starts with 0. Hence the x data are [0, 1, 2, 3].

# %% [markdown]
# We can specify the x values separately. Let us try by mentioning the values.

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.show()

# %% [markdown]
# # Giving label to the x and y axis

# %% [markdown]
# We can label the xaxis and the yaxis which makes it easier to understand the data displayed in the graph.

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.xlabel("XVALUES")
plt.ylabel("YVALUES")
plt.show()

# %% [markdown]
# # we can also add title to the graph.

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.xlabel("XVALUES")
plt.ylabel("YVALUES")
plt.title("Data Graph")
plt.show()

# %% [markdown]
# # Change size of the graph

# %% [markdown]
# Using figsize
#
# figsize() takes two parameters- width and height (in inches). By default the values for width and height are 6.4 and 4.8 respectively.
#
# Syntax:
#
# plt.figure(figsize=(x,y))

# %%
plt.figure(figsize=(10,10))
plt.plot([1,2,3,4],[1,4,9,16])
plt.xlabel("XVALUES")
plt.ylabel("YVALUES")
plt.title("Data Graph")
plt.show()

# %% [markdown]
# # Save the graph

# %%
# %matplotlib inline
# %matplotlib notebook 
plt.figure(figsize=(10,10))
plt.plot([1,2,3,4],[1,4,9,16])
plt.xlabel("XVALUES")
plt.ylabel("YVALUES")
plt.title("Data Graph")
plt.show()
plt.savefig("C:/Users/Lenovo/Desktop/datagraph.pdf")
# Out:
# <img src="data:image/png;base64,..." width="720">

# %% [markdown]
# # Plot Graph from Dataset

# %%
import pandas as pd 
#dt=pd.read_csv("C:/Users/Lenovo/Desktop/JaipurFinalCleanData.csv")
dt=pd.read_csv("C:/Users/Lenovo/Desktop/JaipurFinalCleanData.csv")
dt.head()
# Out:
#          date  mean_temperature  max_temperature  min_temperature  \
# 0  2016-05-04                34               41               27
# 1  2016-05-05                31               38               24
# 2  2016-05-06                28               34               21
# 3  2016-05-07                30               38               23
# 4  2016-05-08                34               41               26
#
#    Mean_dew_pt  mean_pressure  max_humidity  min_humidity  max_dew_pt_1  \
# 0            6        1006.00            27             5            12
# 1            7        1005.65            29             6            13
# 2           11        1007.94            61            13            16
# 3           13        1008.39            69            18            17
# 4           10        1007.62            50             8            14
#
#    max_dew_pt_2  min_dew_pt_1  min_dew_pt_2  max_pressure_1  max_pressure_2  \
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
x=dt.date
y=dt.mean_temperature
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Scatter plot

# %%
import matplotlib.pyplot as plt
import numpy as np
x=dt.date# x axis values is taken from date of jaipurcleandata csv file 
y=dt.mean_temperature # yaxis values is taken from mean_temperature  of jaipurcleandata csv file
plt.scatter(x,y)
plt.show()

# %% [markdown]
# Do you see that the x axis is filled with a thick line, and that there's no tick label available? This makes us unable to analyze the data.
#
# Let's try to modify this scatter plot so that we can see the ticks!
#
# Choose only several ticks
# One reason why there's a thick bar below the x axis is that there are numerous labels (2 years daily data) on the x axis.
#
# The first thing we are going to do is to then reduce the number of ticks/ points for the x axis. We do this using the np.arrange function as below:

# %%
import matplotlib.pyplot as plt
import numpy as np
x=dt.date # x axis values is taken from date of jaipurcleandata csv file 
y=dt.mean_temperature # yaxis values is taken from mean_temperature  of jaipurcleandata csv file
plt.scatter(x,y)
# np.arange function is used to reduce the no of x axis /y axis values
# np.arange(start,stop.interval),more the interval lessee will be the values
plt.xticks(np.arange(0,700,180))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
import matplotlib.pyplot as plt
import numpy as np
x=dt.date
y=dt.mean_temperature
plt.scatter(x,y)
plt.xticks(np.arange(0,700,180))
#
plt.xticks(rotation=30)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# Change the default figure size
plt.figure(figsize=(7,7))
x=dt.date
y=dt.mean_temperature
plt.scatter(x,y)
plt.xticks(np.arange(0,700,180))
plt.xticks(rotation=30)

# Add x and y labels, title and set a font size
plt.xlabel("Date",fontsize=14)
plt.ylabel("MeanTemperature",fontsize=14)
plt.title("MEAN  TEMPERATURE OF JAIPUR",fontsize=18)

plt.show()

# %% [markdown]
# # Increasing the fontsize of x & y ticks

# %% [markdown]
# # Displaying the x values in specified angle using rotation ()

# %%
plt.figure(figsize=(7,7))
x=dt.date
y=dt.mean_temperature
plt.scatter(x,y)

plt.xticks(fontsize=12)# font size of xticks is specified
plt.yticks(fontsize=12)#font size of yticks is specified

plt.xticks(np.arange(0,700,180))

#Change x ticks interval so that you can see the dates clearly
plt.xticks(rotation=30)

plt.xlabel("Date",fontsize=14)
plt.ylabel("MeanTemperature",fontsize=14)
plt.title("MEAN  TEMPERATURE OF JAIPUR",fontsize=18)
plt.show()
